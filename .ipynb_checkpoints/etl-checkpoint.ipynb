# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
import h5py
from sql_queries import *

# %%
def process_song_file(cur, filepath):
    """Execute ETL process on song data inserting data into a song and artist table
    
    Parameters: 
        cur (object) - database cursor
        filepath (object) - path to song data on S3
    Returns: 
        None
    """       
    # Read content in h5 file
    file = h5py.File(filepath, 'r')
    
    # Access groups and receive data via key following the hierarchy in h5 file 
    group_metadata = file['metadata']
    group_analysis = file['analysis']
    group_musicbrainz = file['musicbrainz']
    
    data_metadata_songs = group_metadata['songs'].value
    data_analysis_songs = group_analysis['songs'].value
    data_musicbrainz_songs = group_musicbrainz['songs'].value
    
    # Decode binary data format and flatten dataset for insert 
    artist_data = list([data_metadata_songs[0][4].decode('utf-8'), data_metadata_songs[0][9].decode('utf-8'),
                        data_metadata_songs[0][5].item(), data_metadata_songs[0][7].item()])
    
    song_data = list([data_metadata_songs[0][17].decode('utf-8'), data_metadata_songs[0][4].decode('utf-8'), 
                      data_metadata_songs[0][18].decode('utf-8'), data_metadata_songs[0][14].decode('utf-8'),
                      data_musicbrainz_songs[0][1].item(), data_analysis_songs[0][3].item()])
    
    # Fill artist and song table
    cur.execute(artist_table_insert, artist_data)
    cur.execute(song_table_insert, song_data)

# %%
def process_log_file(cur, filepath):
    """
    Extract data in log files from datasource and manage the transformation of the data
    
    Parameters: 
        cur (object) - database cursor
        filepath (object) - path to song log data on S3
    Returns: 
        None
    """    
    # Read content in json file and filter by NextSong
    file = pd.read_json(filepath, lines=True)
    data = file[file.page == 'NextSong']
    
    # Transform time, user, songplays data and insert them to respective tables
    transform_time_data(data, cur)
    transform_user_data(data, cur)
    transform_songplay_data(data, cur) 
        
def transform_time_data(data, cur):
    """
    Transform and load log data containing time related details
    about played songs into time table
    
    Parameters: 
        data (object) - pd dataframe containing log data
    Returns: 
        None
    """
    
    # Convert timestamp column to datetime (in ms)
    timestamp_series = data.ts
    datetime_series = pd.to_datetime(timestamp_series, unit='ms') 

    # Extract timedata details and name columns
    timedata = [timestamp_series, datetime_series.dt.hour, datetime_series.dt.day, 
                datetime_series.dt.week, 
                datetime_series.dt.month, datetime_series.dt.year, 
                datetime_series.dt.weekday]
    column_labels = ['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']

    # Combine timedata and labels
    labeled_timedata = dict(zip(column_labels, timedata))

    # Iterate through dataframe and insert each row in time table
    time_df = pd.DataFrame(data=labeled_timedata)
    for i, row in time_df.iterrows():
        cur.execute(time_table_insert, list(row))
        
def transform_user_data(data, cur):
    """
    Transform and load log data containing user details into user table
    
    Parameters: 
        data (object) - pd dataframe containing log data
    Returns: 
        None
    """
    # Remove user duplicates and create user dataframe
    user_df = data[['userId', 'firstName', 'lastName', 'gender', 'level']].drop_duplicates('userId')

    # Insert user records in user table
    for i, row in user_df.iterrows():
        cur.execute(user_table_insert, row)
        
def transform_songplay_data(data, cur):
    """
    Transform and load log data about played songs to songplays table
    
    Parameters: 
        data (object) - pd dataframe containing log data
    Returns: 
        None
    """
    # Get played songs based on user logs and artist- and song ids
    for i, row in data.iterrows():

        # Get songid and artistid from song and artist tables
        # indicating the played songs is available in song datasource
        cur.execute(song_select, (row.song, row.artist))
        results = cur.fetchone()
        
        # Mark played songs as with None when these are not available in own datasource
        if results:
            songid, artistid = results
        else:
            songid, artistid = None, None
   
        # Insert played songs into songplay table
        songplay_data = ([row.ts, row.userId, songid, row.level, artistid, 
                              row.sessionId, row.location, row.userAgent])
        cur.execute(songplay_table_insert, songplay_data)

# %%
def process_data(cur, conn, filepath, func, filetyp):
    """ 
    Establish the connection to database and process song and log data from external datasource
    
    Parameters: 
        cur (object) - database cursor
        conn (object) - database connection details
        filepath (string) - path to song or log data
        func (function) - process song or log file function
        filetyp (string) - filetyp of datasource (.h5 or .json)
    Returns: 
        None
    """ 
    # Get all files matching extension from directory
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root, filetyp))
        for f in files :
            all_files.append(os.path.abspath(f))

    # Get total number of files found
    num_files = len(all_files)
    print('{} files found in {}'.format(num_files, filepath))

    # Apply processing function on respective file 
    for i, datafile in enumerate(all_files, 1):
        func(cur, datafile)
        conn.commit()
        print('{}/{} files processed.'.format(i, num_files))

# %%
def main():
    """
    Establish the connection to database and process song and log data from external datasource
    
    Parameters: 
        None
    Returns: 
        None
    """ 
    conn = psycopg2.connect("host=localhost dbname=musicdb")
    cur = conn.cursor()
    process_data(cur, conn, filepath='data/song_data', func=process_song_file, filetyp='*.h5')
    process_data(cur, conn, filepath='data/log_data', func=process_log_file, filetyp='*.json')

if __name__ == "__main__":
    main()
# Out:
# 625 files found in data/song_data
# 1/625 files processed.
# 2/625 files processed.
# 3/625 files processed.
# 4/625 files processed.
# 5/625 files processed.
# 6/625 files processed.
# 7/625 files processed.
# 8/625 files processed.
# 9/625 files processed.
# 10/625 files processed.
# 11/625 files processed.
# 12/625 files processed.
# 13/625 files processed.
# 14/625 files processed.
# 15/625 files processed.
# 16/625 files processed.
# 17/625 files processed.
# 18/625 files processed.
# 19/625 files processed.
# C:\Users\matthias.reichel\Anaconda\lib\site-packages\h5py\_hl\dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 20/625 files processed.
# 21/625 files processed.
# 22/625 files processed.
# 23/625 files processed.
# 24/625 files processed.
# 25/625 files processed.
# 26/625 files processed.
# 27/625 files processed.
# 28/625 files processed.
# 29/625 files processed.
# 30/625 files processed.
# 31/625 files processed.
# 32/625 files processed.
# 33/625 files processed.
# 34/625 files processed.
# 35/625 files processed.
# 36/625 files processed.
# 37/625 files processed.
# 38/625 files processed.
# 39/625 files processed.
# 40/625 files processed.
# 41/625 files processed.
# 42/625 files processed.
# 43/625 files processed.
# 44/625 files processed.
# 45/625 files processed.
# 46/625 files processed.
# 47/625 files processed.
# 48/625 files processed.
# 49/625 files processed.
# 50/625 files processed.
# 51/625 files processed.
# 52/625 files processed.
# 53/625 files processed.
# 54/625 files processed.
# 55/625 files processed.
# 56/625 files processed.
# 57/625 files processed.
# 58/625 files processed.
# 59/625 files processed.
# 60/625 files processed.
# 61/625 files processed.
# 62/625 files processed.
# 63/625 files processed.
# 64/625 files processed.
# 65/625 files processed.
# 66/625 files processed.
# 67/625 files processed.
# 68/625 files processed.
# 69/625 files processed.
# 70/625 files processed.
# 71/625 files processed.
# 72/625 files processed.
# 73/625 files processed.
# 74/625 files processed.
# 75/625 files processed.
# 76/625 files processed.
# 77/625 files processed.
# 78/625 files processed.
# 79/625 files processed.
# 80/625 files processed.
# 369/625 files processed.
# 370/625 files processed.
# 371/625 files processed.
# 372/625 files processed.
# 373/625 files processed.
# 374/625 files processed.
# 375/625 files processed.
# 376/625 files processed.
# 377/625 files processed.
# 378/625 files processed.
# 379/625 files processed.
# 380/625 files processed.
# 381/625 files processed.
# 382/625 files processed.
# 383/625 files processed.
# 384/625 files processed.
# 385/625 files processed.
# 386/625 files processed.
# 387/625 files processed.
# 388/625 files processed.
# 389/625 files processed.
# 390/625 files processed.
# 391/625 files processed.
# 392/625 files processed.
# 393/625 files processed.
# 394/625 files processed.
# 395/625 files processed.
# 396/625 files processed.
# 397/625 files processed.
# 398/625 files processed.
# 399/625 files processed.
# 400/625 files processed.
# 401/625 files processed.
# 402/625 files processed.
# 403/625 files processed.
# 404/625 files processed.
# 405/625 files processed.
# 406/625 files processed.
# 407/625 files processed.
# 408/625 files processed.
# 409/625 files processed.
# 410/625 files processed.
# 411/625 files processed.
# 412/625 files processed.
# 413/625 files processed.
# 414/625 files processed.
# 415/625 files processed.
# 416/625 files processed.
# 417/625 files processed.
# 418/625 files processed.
# 419/625 files processed.
# 420/625 files processed.
# 421/625 files processed.
# 422/625 files processed.
# 423/625 files processed.
# 424/625 files processed.
# 425/625 files processed.
# 426/625 files processed.
# 427/625 files processed.
# 428/625 files processed.
# 429/625 files processed.
# 430/625 files processed.
# 431/625 files processed.
# 432/625 files processed.
# 433/625 files processed.
# 434/625 files processed.
# 435/625 files processed.
# 436/625 files processed.
# 437/625 files processed.
# 438/625 files processed.
# 439/625 files processed.
# 440/625 files processed.
# 441/625 files processed.
# 442/625 files processed.
# 443/625 files processed.
# 444/625 files processed.
# 445/625 files processed.
# 446/625 files processed.
# 447/625 files processed.
# 448/625 files processed.
# 449/625 files processed.
# 450/625 files processed.
# 451/625 files processed.
# 452/625 files processed.
# 453/625 files processed.
# 454/625 files processed.
# 455/625 files processed.
# 456/625 files processed.
# 457/625 files processed.
# 458/625 files processed.
# 459/625 files processed.
# 460/625 files processed.
# 461/625 files processed.
# 462/625 files processed.
# 463/625 files processed.
# 464/625 files processed.
# 465/625 files processed.
# 466/625 files processed.
# 467/625 files processed.
# 468/625 files processed.
# 469/625 files processed.
# 470/625 files processed.
# 471/625 files processed.
# 472/625 files processed.
# 473/625 files processed.
# 474/625 files processed.
# 475/625 files processed.
# 476/625 files processed.
# 477/625 files processed.
# 478/625 files processed.
# 479/625 files processed.
# 480/625 files processed.
# 481/625 files processed.
# 482/625 files processed.
# 483/625 files processed.
# 484/625 files processed.
# 485/625 files processed.
# 486/625 files processed.
# 487/625 files processed.
# 488/625 files processed.
# 489/625 files processed.
# 490/625 files processed.
# 491/625 files processed.
# 492/625 files processed.
# 493/625 files processed.
# 494/625 files processed.
# 495/625 files processed.
# 496/625 files processed.
# 497/625 files processed.
# 498/625 files processed.
# 499/625 files processed.
# 500/625 files processed.
# 501/625 files processed.
# 502/625 files processed.
# 503/625 files processed.
# 504/625 files processed.
# 505/625 files processed.
# 506/625 files processed.
# 507/625 files processed.
# 508/625 files processed.
# 509/625 files processed.
# 510/625 files processed.
# 511/625 files processed.
# 512/625 files processed.
# 513/625 files processed.
# 514/625 files processed.
# 515/625 files processed.
# 516/625 files processed.
# 517/625 files processed.
# 518/625 files processed.
# 519/625 files processed.
# 520/625 files processed.
# 521/625 files processed.
# 522/625 files processed.
# 523/625 files processed.
# 524/625 files processed.
# 525/625 files processed.
# 526/625 files processed.
# 527/625 files processed.
# 528/625 files processed.
# 529/625 files processed.
# 530/625 files processed.
# 531/625 files processed.
# 532/625 files processed.
# 533/625 files processed.
# 534/625 files processed.
# 535/625 files processed.
# 536/625 files processed.
# 537/625 files processed.
# 538/625 files processed.
# 539/625 files processed.
# 540/625 files processed.
# 541/625 files processed.
# 542/625 files processed.
# 543/625 files processed.
# 544/625 files processed.
# 545/625 files processed.
# 546/625 files processed.
# 547/625 files processed.
# 548/625 files processed.
# 549/625 files processed.
# 550/625 files processed.
# 551/625 files processed.
# 552/625 files processed.
# 553/625 files processed.
# 554/625 files processed.
# 555/625 files processed.
# 556/625 files processed.
# 557/625 files processed.
# 558/625 files processed.
# 559/625 files processed.
# 560/625 files processed.
# 561/625 files processed.
# 562/625 files processed.
# 563/625 files processed.
# 564/625 files processed.
# 565/625 files processed.
# 566/625 files processed.
# 567/625 files processed.
# 568/625 files processed.
# 569/625 files processed.
# 570/625 files processed.
# 571/625 files processed.
# 572/625 files processed.
# 573/625 files processed.
# 574/625 files processed.
# 575/625 files processed.
# 576/625 files processed.
# 577/625 files processed.
# 578/625 files processed.
# 579/625 files processed.
# 580/625 files processed.
# 581/625 files processed.
# 582/625 files processed.
# 583/625 files processed.
# 584/625 files processed.
# 585/625 files processed.
# 586/625 files processed.
# 587/625 files processed.
# 588/625 files processed.
# 589/625 files processed.
# 590/625 files processed.
# 591/625 files processed.
# 592/625 files processed.
# 593/625 files processed.
# 594/625 files processed.
# 595/625 files processed.
# 596/625 files processed.
# 597/625 files processed.
# 598/625 files processed.
# 599/625 files processed.
# 600/625 files processed.
# 601/625 files processed.
# 602/625 files processed.
# 603/625 files processed.
# 604/625 files processed.
# 605/625 files processed.
# 606/625 files processed.
# 607/625 files processed.
# 608/625 files processed.
# 609/625 files processed.
# 610/625 files processed.
# 611/625 files processed.
# 612/625 files processed.
# 613/625 files processed.
# 614/625 files processed.
# 615/625 files processed.
# 616/625 files processed.
# 617/625 files processed.
# 618/625 files processed.
# 619/625 files processed.
# 620/625 files processed.
# 621/625 files processed.
# 622/625 files processed.
# 623/625 files processed.
# 624/625 files processed.
# 625/625 files processed.
# 30 files found in data/log_data
# 1/30 files processed.
# 2/30 files processed.
# 3/30 files processed.
# 4/30 files processed.
# 5/30 files processed.
# 6/30 files processed.
# 7/30 files processed.
# 8/30 files processed.
# 9/30 files processed.
# 10/30 files processed.
# 11/30 files processed.
# 12/30 files processed.
# 13/30 files processed.
# 14/30 files processed.
# 15/30 files processed.
# 16/30 files processed.
# 17/30 files processed.
# 18/30 files processed.
# 19/30 files processed.
# 20/30 files processed.
# 21/30 files processed.
# 22/30 files processed.
# 23/30 files processed.
# 24/30 files processed.
# 25/30 files processed.
# 26/30 files processed.
# 27/30 files processed.
# 28/30 files processed.
# 29/30 files processed.
# 30/30 files processed.
